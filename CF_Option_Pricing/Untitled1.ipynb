# %%
import pandas as pd
import glob
import os
import numpy as np

# %%
path_1 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/' # use your path
all_files_1 = glob.glob(os.path.join(path_1 , "*.csv"))

path_2 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/' # use your path
all_files_2 = glob.glob(os.path.join(path_2 , "*.csv"))

path_3 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_05/1_5/' # use your path
all_files_3 = glob.glob(os.path.join(path_3 , "*.csv"))

path_4 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_05/2/' # use your path
all_files_4 = glob.glob(os.path.join(path_4 , "*.csv"))

path_5 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_15/1_5/' # use your path
all_files_5 = glob.glob(os.path.join(path_5 , "*.csv"))

path_6 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_15/2/' # use your path
all_files_6 = glob.glob(os.path.join(path_6 , "*.csv"))

path_7 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_1/1_5/' # use your path
all_files_7 = glob.glob(os.path.join(path_7 , "*.csv"))

path_8 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_1/2/' # use your path
all_files_8 = glob.glob(os.path.join(path_8 , "*.csv"))

path_9 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_05/1_5/' # use your path
all_files_9 = glob.glob(os.path.join(path_9 , "*.csv"))

path_10 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_05/2/' # use your path
all_files_10 = glob.glob(os.path.join(path_10 , "*.csv"))

path_11 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_15/1_5/' # use your path
all_files_11 = glob.glob(os.path.join(path_11 , "*.csv"))

path_12 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_15/2/' # use your path
all_files_12 = glob.glob(os.path.join(path_12 , "*.csv"))

# %%
print(all_files_1)

print("----------------------")
print(all_files_11[0])
print(all_files_11[1])
print(all_files_11[2])
print(all_files_11[3])
print(all_files_11[4])
print(all_files_11[5])
# Out:
# ['/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_Vega_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_rho_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_theta_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_call_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_gamma_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_delta_m_0_v_1_l_01_1.csv']
# ----------------------
# /Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_15/1_5/DG_theta_m_0.5_v_1.5_l_01_1.csv
# /Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_15/1_5/DG_gamma_m_0.5_v_1.5_l_01_1.csv
# ...

# %%
# m 0 v 1 -----------------------------------------------------------------------------

# call
call_1 = all_files_1[3]
call_2 = all_files_2[3]

# delta
delta_1 = all_files_1[5]
delta_2 = all_files_2[5]

# gamma
gamma_1 = all_files_1[4]
gamma_2 = all_files_2[4]

# theta
theta_1 = all_files_1[2]
theta_2 = all_files_2[2]

# Vega
vega_1 = all_files_1[0]
vega_2 = all_files_2[0]

# rho
rho_1 = all_files_1[1]
rho_2 = all_files_2[1]

# m_0_v_05-----------------------------------------------------------------------------
# call
call_3 = all_files_3[4]
call_4 = all_files_4[3]

# delta
delta_3 = all_files_3[3]
delta_4 = all_files_4[4]

# gamma
gamma_3 = all_files_3[1]
gamma_4 = all_files_4[1]

# theta
theta_3 = all_files_3[2]
theta_4 = all_files_4[0]

# Vega
vega_3 = all_files_3[0]
vega_4 = all_files_4[2]

# rho
rho_3 = all_files_3[5]
rho_4 = all_files_4[5]

# m_0_v_15-----------------------------------------------------------------------------
# call
call_5 = all_files_5[3]
call_6 = all_files_6[3]

# delta
delta_5 = all_files_5[5]
delta_6 = all_files_6[5]

# gamma
gamma_5 = all_files_5[0]
gamma_6 = all_files_6[0]

# theta
theta_5 = all_files_5[1]
theta_6 = all_files_6[1]

# Vega
vega_5 = all_files_5[2]
vega_6 = all_files_6[2]

# rho
rho_5 = all_files_5[4]
rho_6 = all_files_6[4] 
# m_05_v_1-----------------------------------------------------------------------------
# call
call_7 = all_files_7[4]
call_8 = all_files_8[4]

# delta
delta_7 = all_files_7[0]
delta_8 = all_files_8[0]

# gamma
gamma_7 = all_files_7[1]
gamma_8 = all_files_8[1]

# theta
theta_7 = all_files_7[2]
theta_8 = all_files_8[2]

# Vega
vega_7 = all_files_7[5]
vega_8 = all_files_8[5]

# rho
rho_7 = all_files_7[3]
rho_8 = all_files_8[3]

# m_05_v_05-----------------------------------------------------------------------------

# call
call_9 = all_files_9[4]
call_10 = all_files_10[4]

# delta
delta_9 = all_files_9[0]
delta_10 = all_files_10[0]

# gamma
gamma_9 = all_files_9[1]
gamma_10 = all_files_10[1]

# theta
theta_9 = all_files_9[2]
theta_10 = all_files_10[2]

# Vega
vega_9 = all_files_9[5]
vega_10 = all_files_10[5]

# rho
rho_9 = all_files_9[3]
rho_10 = all_files_10[3]
# m_05_v_15-----------------------------------------------------------------------------
# call
call_11 = all_files_11[3]
call_12 = all_files_12[3]

# delta
delta_11 = all_files_11[2]
delta_12 = all_files_12[2]

# gamma
gamma_11 = all_files_11[1]
gamma_12 = all_files_12[1]

# theta
theta_11 = all_files_11[0]
theta_12 = all_files_12[0]

# Vega
vega_11 = all_files_11[5]
vega_12 = all_files_12[5]

# rho
rho_11 = all_files_11[4]
rho_12 = all_files_12[4]

# %%
dfa1 = pd.read_csv(delta_11, index_col=None, header=0)
dfa2 = pd.read_csv(gamma_11, index_col=None, header=0)
dfa3 = pd.read_csv(theta_11, index_col=None, header=0)
dfa4 = pd.read_csv(vega_11, index_col=None, header=0)
dfa5 = pd.read_csv(rho_11, index_col=None, header=0)

# delta
# gamma
# theta
# vega
# rho

# %%
dfb1 = pd.read_csv(delta_12, index_col=None, header=0)
dfb2 = pd.read_csv(gamma_12, index_col=None, header=0)
dfb3 = pd.read_csv(theta_12, index_col=None, header=0)
dfb4 = pd.read_csv(vega_12, index_col=None, header=0)
dfb5 = pd.read_csv(rho_12, index_col=None, header=0)
# delta
# gamma
# theta
# vega
# rho

# %%
df01 = dfa1.iloc[89,1:]
df11 = dfa1.iloc[99,1:]
df21 = dfa1.iloc[109,1:]
df31 = pd.concat([df01,df11, df21], axis=1)
# print(df31)
# print("----------------------------")
df31 = np.array(df31)
# print(df31)

shape11 = np.shape(df31)[0]
shape21 = np.shape(df31)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape11):
    a = ''
    for j in range(shape21):
        a = a + f' & {np.round(df31[i][j],4)}'
    print(a)
    
    
df02 = dfa2.iloc[89,1:]
df12 = dfa2.iloc[99,1:]
df22 = dfa2.iloc[109,1:]
df32 = pd.concat([df02,df12, df22], axis=1)
# print(df31)
# print("----------------------------")
df32 = np.array(df32)
# print(df31)

shape12 = np.shape(df32)[0]
shape22 = np.shape(df32)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape12):
    a = ''
    for j in range(shape22):
        a = a + f' & {np.round(df32[i][j],4)}'
    print(a)
    
    
df03 = dfa3.iloc[89,1:]
df13 = dfa3.iloc[99,1:]
df23 = dfa3.iloc[109,1:]
df33 = pd.concat([df03,df13, df23], axis=1)
# print(df33)
# print("----------------------------")
df33 = np.array(df33)
# print(df33)

shape13 = np.shape(df33)[0]
shape23 = np.shape(df33)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape13):
    a = ''
    for j in range(shape23):
        a = a + f' & {np.round(df33[i][j],4)}'
    print(a)
    
df04 = dfa4.iloc[89,1:]
df14 = dfa4.iloc[99,1:]
df24 = dfa4.iloc[109,1:]
df34 = pd.concat([df04,df14, df24], axis=1)
# print(df31)
# print("----------------------------")
df34 = np.array(df34)
# print(df31)

shape14 = np.shape(df34)[0]
shape24 = np.shape(df34)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape14):
    a = ''
    for j in range(shape24):
        a = a + f' & {np.round(df34[i][j],4)}'
    print(a)
    
df05 = dfa5.iloc[89,1:]
df15 = dfa5.iloc[99,1:]
df25 = dfa5.iloc[109,1:]
df35 = pd.concat([df05,df15, df25], axis=1)
# print(df31)
# print("----------------------------")
df35 = np.array(df35)
# print(df31)

shape15 = np.shape(df35)[0]
shape25 = np.shape(df35)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape15):
    a = ''
    for j in range(shape21):
        a = a + f' & {np.round(df35[i][j],4)}'
    print(a)
# Out:
# ----------------------------
# ----------------------------
#
#  & 0.0008 & 0.0064 & 0.0298
#  & 0.0214 & 0.0884 & 0.2241
#  & 0.053 & 0.1732 & 0.3625
#  & 0.0799 & 0.2325 & 0.4438
#  & 0.1014 & 0.2751 & 0.4968
#  & 0.1197 & 0.3086 & 0.5359
#  & 0.1368 & 0.3385 & 0.5691
#  & 0.1564 & 0.3708 & 0.6035
# ----------------------------
# ----------------------------
#
#  & 0.0002 & 0.0012 & 0.0038
#  & 0.0037 & 0.0101 & 0.0166
#  & 0.0078 & 0.0162 & 0.0205
#  & 0.0107 & 0.0193 & 0.0216
#  & 0.0128 & 0.0211 & 0.0217
#  & 0.0144 & 0.0223 & 0.0216
#  & 0.0158 & 0.0232 & 0.0214
#  & 0.0174 & 0.024 & 0.0211
# ----------------------------
# ----------------------------
#
#  & 0.0319 & 0.4199 & 2.6902
#  & 0.1771 & 2.4088 & 10.4382
#  & -0.198 & 2.2828 & 10.8509
#  & -0.795 & 1.3545 & 9.3897
#  & -1.4076 & 0.3183 & 7.7308
#  & -2.0052 & -0.7031 & 6.1274
#  & -2.628 & -1.7625 & 4.4987
#  & -3.405 & -3.0691 & 2.533
# ----------------------------
# ----------------------------
#
# ...

# %%
df01 = dfb1.iloc[89,1:]
df11 = dfb1.iloc[99,1:]
df21 = dfb1.iloc[109,1:]
df31 = pd.concat([df01,df11, df21], axis=1)
# print(df31)
# print("----------------------------")
df31 = np.array(df31)
# print(df31)

shape11 = np.shape(df31)[0]
shape21 = np.shape(df31)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape11):
    a = ''
    for j in range(shape21):
        a = a + f' & {np.round(df31[i][j],4)}'
    print(a)
    
    
df02 = dfb2.iloc[89,1:]
df12 = dfb2.iloc[99,1:]
df22 = dfb2.iloc[109,1:]
df32 = pd.concat([df02,df12, df22], axis=1)
# print(df31)
# print("----------------------------")
df32 = np.array(df32)
# print(df31)

shape12 = np.shape(df32)[0]
shape22 = np.shape(df32)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape12):
    a = ''
    for j in range(shape22):
        a = a + f' & {np.round(df32[i][j],4)}'
    print(a)
    
    
df03 = dfb3.iloc[89,1:]
df13 = dfb3.iloc[99,1:]
df23 = dfb3.iloc[109,1:]
df33 = pd.concat([df03,df13, df23], axis=1)
# print(df33)
# print("----------------------------")
df33 = np.array(df33)
# print(df33)

shape13 = np.shape(df33)[0]
shape23 = np.shape(df33)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape13):
    a = ''
    for j in range(shape23):
        a = a + f' & {np.round(df33[i][j],4)}'
    print(a)
    
df04 = dfb4.iloc[89,1:]
df14 = dfb4.iloc[99,1:]
df24 = dfb4.iloc[109,1:]
df34 = pd.concat([df04,df14, df24], axis=1)
# print(df31)
# print("----------------------------")
df34 = np.array(df34)
# print(df31)

shape14 = np.shape(df34)[0]
shape24 = np.shape(df34)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape14):
    a = ''
    for j in range(shape24):
        a = a + f' & {np.round(df34[i][j],4)}'
    print(a)
    
df05 = dfb5.iloc[89,1:]
df15 = dfb5.iloc[99,1:]
df25 = dfb5.iloc[109,1:]
df35 = pd.concat([df05,df15, df25], axis=1)
# print(df31)
# print("----------------------------")
df35 = np.array(df35)
# print(df31)

shape15 = np.shape(df35)[0]
shape25 = np.shape(df35)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape15):
    a = ''
    for j in range(shape21):
        a = a + f' & {np.round(df35[i][j],4)}'
    print(a)
# Out:
# ----------------------------
# ----------------------------
#
#  & 0.0221 & 0.0907 & 0.2289
#  & 0.0673 & 0.2061 & 0.4095
#  & 0.0993 & 0.2714 & 0.4932
#  & 0.1215 & 0.3123 & 0.5409
#  & 0.1384 & 0.3414 & 0.5731
#  & 0.1526 & 0.365 & 0.5982
#  & 0.1662 & 0.3867 & 0.6207
#  & 0.1821 & 0.4111 & 0.6451
# ----------------------------
# ----------------------------
#
#  & 0.0038 & 0.0104 & 0.0168
#  & 0.0094 & 0.0181 & 0.0213
#  & 0.0126 & 0.021 & 0.0219
#  & 0.0146 & 0.0225 & 0.0217
#  & 0.016 & 0.0233 & 0.0215
#  & 0.0171 & 0.0239 & 0.0212
#  & 0.0181 & 0.0244 & 0.0209
#  & 0.0192 & 0.0249 & 0.0205
# ----------------------------
# ----------------------------
#
#  & 0.1731 & 2.4239 & 10.5048
#  & -0.493 & 1.8363 & 10.1556
#  & -1.3455 & 0.4103 & 7.8589
#  & -2.0724 & -0.8337 & 5.8994
#  & -2.6895 & -1.8827 & 4.2885
#  & -3.2508 & -2.8278 & 2.8655
#  & -3.8207 & -3.7783 & 1.4568
#  & -4.5223 & -4.9328 & -0.2257
# ----------------------------
# ----------------------------
#
# ...
