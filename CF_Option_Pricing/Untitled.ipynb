# %%
import pandas as pd
import os
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np

# %%
# /Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE

# %%
df1 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_0_v_1/DE_m_0_v_1_l_01_1.csv') 
df2 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_0_v_1/DE_m_0_v_1_l_005_1.csv') 

df3 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_0_v_05/DE_m_0_v_05_l_01_1.csv')
df4 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_0_v_05/DE_m_0_v_05_l_005_1.csv') 

df5 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_0_v_15/DE_m_0_v_15_l_01_1.csv') 
df6 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_0_v_15/DE_m_0_v_15_l_005_1.csv') 


df7 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_05_v_1/DE_m_05_v_1_l_01_1.csv')
df8 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_05_v_1/DE_m_05_v_1_l_005_1.csv') 

df9 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_05_v_05/DE_m_05_v_05_l_01_1.csv') 
df10 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_05_v_05/DE_m_05_v_05_l_005_1.csv') 

df11 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_05_v_15/DE_m_05_v_15_l_01_1.csv')
df12 = pd.read_csv('/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DE/m_05_v_15/DE_m_05_v_15_l_005_1.csv')

# %%
df1
# Out:
#        S        call     delta     gamma      Vega      theta        rho
# 0      1   -0.000462 -0.000650 -0.000264 -0.000010   0.001422  -0.000047
# 1      2   -0.001225 -0.000862 -0.000175 -0.000026   0.003732  -0.000125
# 2      3   -0.002166 -0.001016 -0.000138 -0.000046   0.006560  -0.000220
# 3      4   -0.003247 -0.001142 -0.000116 -0.000070   0.009789  -0.000330
# 4      5   -0.004444 -0.001250 -0.000101 -0.000095   0.013352  -0.000451
# ..   ...         ...       ...       ...       ...        ...        ...
# 244  245  134.288028  0.930717 -0.000101 -0.226263  40.530608  23.432676
# 245  246  135.218667  0.930574 -0.000100 -0.227783  40.793202  23.426512
# 246  247  136.149205  0.930497 -0.000100 -0.229305  41.056168  23.420332
# 247  248  137.079643  0.930397 -0.000100 -0.230828  41.319473  23.414136
# 248  249  138.009980  0.930287 -0.000100 -0.232352  41.583195  23.407924
#
# [249 rows x 7 columns]

# %%
df2
# Out:
#        S        call     delta     gamma      Vega      theta        rho
# 0      1   -0.000259 -0.000366 -0.000152 -0.000006   0.000932  -0.000027
# 1      2   -0.000690 -0.000488 -0.000101 -0.000015   0.002468  -0.000071
# 2      3   -0.001224 -0.000577 -0.000079 -0.000027   0.004361  -0.000126
# 3      4   -0.001838 -0.000649 -0.000067 -0.000040   0.006531  -0.000190
# 4      5   -0.002520 -0.000712 -0.000059 -0.000055   0.008935  -0.000260
# ..   ...         ...       ...       ...       ...        ...        ...
# 244  245  139.784156  0.962999 -0.000053 -0.118760  20.354926  24.037529
# 245  246  140.747127  0.962962 -0.000053 -0.119554  20.499630  24.034294
# 246  247  141.710045  0.962876 -0.000053 -0.120348  20.644518  24.031050
# 247  248  142.672911  0.962832 -0.000053 -0.121143  20.789571  24.027798
# 248  249  143.635723  0.962797 -0.000052 -0.121939  20.934823  24.024538
#
# [249 rows x 7 columns]

# %%
df3
# Out:
#        S        call     delta     gamma      Vega     theta        rho
# 0      1    0.000127  0.000252  0.000249  0.000009 -0.000530   0.000031
# 2      3    0.000005  0.000002 -3.736029e-08 -1.261123e-08    0.000017
# 3      4    0.000007  0.000002 -2.851270e-08 -1.711078e-08    0.000023
# 4      5    0.000008  0.000002 -2.312113e-08 -2.167950e-08    0.000029
# ..   ...         ...       ...           ...           ...         ...
# 244  245  111.093091  0.847399 -3.492033e-05 -7.860694e-02  123.926471
# 245  246  111.940470  0.847363 -3.480196e-05 -7.899773e-02  124.483731
# 246  247  112.787815  0.847325 -3.469253e-05 -7.938784e-02  125.041132
# 247  248  113.635124  0.847293 -3.458197e-05 -7.977737e-02  125.598622
# 248  249  114.482400  0.847270 -3.447028e-05 -8.016636e-02  126.156228
#
#               rho
# 0   -2.471636e-08
# 1   -5.155444e-08
# 2   -7.925585e-08
# 3   -1.075350e-07
# ...

# %%
S_array = np.array(df1['S'])
call1 = np.array(df1['call'])
call2 = np.array(df2['call'])
call3 = np.array(df3['call'])
call4 = np.array(df4['call'])
call5 = np.array(df5['call'])
call6 = np.array(df6['call'])
call7 = np.array(df7['call'])
call8 = np.array(df8['call'])
call9 = np.array(df9['call'])
call10 = np.array(df10['call'])
call11 = np.array(df11['call'])
call12 = np.array(df12['call'])

delta1 = np.array(df1['delta'])
delta2 = np.array(df2['delta'])
delta3 = np.array(df3['delta'])
delta4 = np.array(df4['delta'])
delta5 = np.array(df5['delta'])
delta6 = np.array(df6['delta'])
delta7 = np.array(df7['delta'])
delta8 = np.array(df8['delta'])
delta9 = np.array(df9['delta'])
delta10 = np.array(df10['delta'])
delta11 = np.array(df11['delta'])
delta12 = np.array(df12['delta'])

gamma1 = np.array(df1['gamma'])
gamma2 = np.array(df2['gamma'])
gamma3 = np.array(df3['gamma'])
gamma4 = np.array(df4['gamma'])
gamma5 = np.array(df5['gamma'])
gamma6 = np.array(df6['gamma'])
gamma7 = np.array(df7['gamma'])
gamma8 = np.array(df8['gamma'])
gamma9 = np.array(df9['gamma'])
gamma10 = np.array(df10['gamma'])
gamma11 = np.array(df11['gamma'])
gamma12 = np.array(df12['gamma'])

Vega1 = np.array(df1['Vega'])
Vega2 = np.array(df2['Vega'])
Vega3 = np.array(df3['Vega'])
Vega4 = np.array(df4['Vega'])
Vega5 = np.array(df5['Vega'])
Vega6 = np.array(df6['Vega'])
Vega7 = np.array(df7['Vega'])
Vega8 = np.array(df8['Vega'])
Vega9 = np.array(df9['Vega'])
Vega10 = np.array(df10['Vega'])
Vega11 = np.array(df11['Vega'])
Vega12 = np.array(df12['Vega'])

theta1 = np.array(df1['theta'])
theta2 = np.array(df2['theta'])
theta3 = np.array(df3['theta'])
theta4 = np.array(df4['theta'])
theta5 = np.array(df5['theta'])
theta6 = np.array(df6['theta'])
theta7 = np.array(df7['theta'])
theta8 = np.array(df8['theta'])
theta9 = np.array(df9['theta'])
theta10 = np.array(df10['theta'])
theta11 = np.array(df11['theta'])
theta12 = np.array(df12['theta'])

rho1 = np.array(df1['rho'])
rho2 = np.array(df2['rho'])
rho3 = np.array(df3['rho'])
rho4 = np.array(df4['rho'])
rho5 = np.array(df5['rho'])
rho6 = np.array(df6['rho'])
rho7 = np.array(df7['rho'])
rho8 = np.array(df8['rho'])
rho9 = np.array(df9['rho'])
rho10 = np.array(df10['rho'])
rho11 = np.array(df11['rho'])
rho12 = np.array(df12['rho'])

# %%
delta1[248]
# Out:
# 0.9302866033067404

# %%
print(S_array[99])

print("&",np.round(delta1[89],4),"&",np.round(delta1[99],4),"&",np.round(delta1[109],4))
print("&",np.round(delta2[89],4),"&",np.round(delta2[99],4),"&",np.round(delta2[109],4))
print("&",np.round(delta3[89],4),"&",np.round(delta3[99],4),"&",np.round(delta3[109],4))
print("&",np.round(delta4[89],4),"&",np.round(delta4[99],4),"&",np.round(delta4[109],4))
print("&",np.round(delta5[89],4),"&",np.round(delta5[99],4),"&",np.round(delta5[109],4))
print("&",np.round(delta6[89],4),"&",np.round(delta6[99],4),"&",np.round(delta6[109],4))
print("&",np.round(delta7[89],4),"&",np.round(delta7[99],4),"&",np.round(delta7[109],4))
print("&",np.round(delta8[89],4),"&",np.round(delta8[99],4),"&",np.round(delta8[109],4))
print("&",np.round(delta9[89],4),"&",np.round(delta9[99],4),"&",np.round(delta9[109],4))
print("&",np.round(delta10[89],4),"&",np.round(delta10[99],4),"&",np.round(delta10[109],4))
print("&",np.round(delta11[89],4),"&",np.round(delta11[99],4),"&",np.round(delta11[109],4))
print("&",np.round(delta12[89],4),"&",np.round(delta12[99],4),"&",np.round(delta12[109],4))
# Out:
# 100
# & 0.2175 & 0.4605 & 0.687
# & 0.2503 & 0.5065 & 0.7327
# & 0.2821 & 0.5404 & 0.7644
# & 0.2843 & 0.5476 & 0.7719
# & 0.1303 & 0.3249 & 0.5496
# & 0.1981 & 0.4334 & 0.6649
# & 0.1314 & 0.3265 & 0.5506
# & 0.1987 & 0.4342 & 0.6652
# & 0.2559 & 0.4933 & 0.7234
# & 0.2691 & 0.5229 & 0.7516
# & 0.0048 & 0.0277 & 0.0929
# & 0.055 & 0.1767 & 0.3651

# %%
print("&",np.round(gamma1[89],4),"&",np.round(gamma1[99],4),"&",np.round(gamma1[109],4))
print("&",np.round(gamma2[89],4),"&",np.round(gamma2[99],4),"&",np.round(gamma2[109],4))
print("&",np.round(gamma3[89],4),"&",np.round(gamma3[99],4),"&",np.round(gamma3[109],4))
print("&",np.round(gamma4[89],4),"&",np.round(gamma4[99],4),"&",np.round(gamma4[109],4))
print("&",np.round(gamma5[89],4),"&",np.round(gamma5[99],4),"&",np.round(gamma5[109],4))
print("&",np.round(gamma6[89],4),"&",np.round(gamma6[99],4),"&",np.round(gamma6[109],4))
print("&",np.round(gamma7[89],4),"&",np.round(gamma7[99],4),"&",np.round(gamma7[109],4))
print("&",np.round(gamma8[89],4),"&",np.round(gamma8[99],4),"&",np.round(gamma8[109],4))
print("&",np.round(gamma9[89],4),"&",np.round(gamma9[99],4),"&",np.round(gamma9[109],4))
print("&",np.round(gamma10[89],4),"&",np.round(gamma10[99],4),"&",np.round(gamma10[109],4))
print("&",np.round(gamma11[89],4),"&",np.round(gamma11[99],4),"&",np.round(gamma11[109],4))
print("&",np.round(gamma12[89],4),"&",np.round(gamma12[99],4),"&",np.round(gamma12[109],4))
# Out:
# & 0.0215 & 0.0252 & 0.019
# & 0.0233 & 0.0258 & 0.0185
# & 0.0238 & 0.0258 & 0.0181
# & 0.0245 & 0.026 & 0.018
# & 0.0152 & 0.0225 & 0.021
# & 0.0202 & 0.0251 & 0.02
# & 0.0153 & 0.0225 & 0.0209
# & 0.0202 & 0.0251 & 0.0199
# & 0.0206 & 0.0251 & 0.0197
# & 0.0229 & 0.0258 & 0.0189
# & 0.001 & 0.004 & 0.0092
# & 0.008 & 0.0163 & 0.0203

# %%
print("&",np.round(Vega1[89],4),"&",np.round(Vega1[99],4),"&",np.round(Vega1[109],4))
print("&",np.round(Vega2[89],4),"&",np.round(Vega2[99],4),"&",np.round(Vega2[109],4))
print("&",np.round(Vega3[89],4),"&",np.round(Vega3[99],4),"&",np.round(Vega3[109],4))
print("&",np.round(Vega4[89],4),"&",np.round(Vega4[99],4),"&",np.round(Vega4[109],4))
print("&",np.round(Vega5[89],4),"&",np.round(Vega5[99],4),"&",np.round(Vega5[109],4))
print("&",np.round(Vega6[89],4),"&",np.round(Vega6[99],4),"&",np.round(Vega6[109],4))
print("&",np.round(Vega7[89],4),"&",np.round(Vega7[99],4),"&",np.round(Vega7[109],4))
print("&",np.round(Vega8[89],4),"&",np.round(Vega8[99],4),"&",np.round(Vega8[109],4))
print("&",np.round(Vega9[89],4),"&",np.round(Vega9[99],4),"&",np.round(Vega9[109],4))
print("&",np.round(Vega10[89],4),"&",np.round(Vega10[99],4),"&",np.round(Vega10[109],4))
print("&",np.round(Vega11[89],4),"&",np.round(Vega11[99],4),"&",np.round(Vega11[109],4))
print("&",np.round(Vega12[89],4),"&",np.round(Vega12[99],4),"&",np.round(Vega12[109],4))
# Out:
# & 6.5296 & 9.4454 & 8.615
# & 7.0926 & 9.6778 & 8.3766
# & 7.2375 & 9.6606 & 8.2255
# & 7.4439 & 9.758 & 8.162
# & 4.6158 & 8.4388 & 9.5208
# & 6.1314 & 9.4055 & 9.0544
# & 4.6422 & 8.442 & 9.4697
# & 6.1433 & 9.3974 & 9.0177
# & 6.2484 & 9.4084 & 8.9429
# & 6.9553 & 9.6882 & 8.5633
# & 0.3053 & 1.5082 & 4.1827
# & 2.4173 & 6.095 & 9.1978

# %%
print("&",np.round(theta1[89],4),"&",np.round(theta1[99],4),"&",np.round(theta1[109],4))
print("&",np.round(theta2[89],4),"&",np.round(theta2[99],4),"&",np.round(theta2[109],4))
print("&",np.round(theta3[89],4),"&",np.round(theta3[99],4),"&",np.round(theta3[109],4))
print("&",np.round(theta4[89],4),"&",np.round(theta4[99],4),"&",np.round(theta4[109],4))
print("&",np.round(theta5[89],4),"&",np.round(theta5[99],4),"&",np.round(theta5[109],4))
print("&",np.round(theta6[89],4),"&",np.round(theta6[99],4),"&",np.round(theta6[109],4))
print("&",np.round(theta7[89],4),"&",np.round(theta7[99],4),"&",np.round(theta7[109],4))
print("&",np.round(theta8[89],4),"&",np.round(theta8[99],4),"&",np.round(theta8[109],4))
print("&",np.round(theta9[89],4),"&",np.round(theta9[99],4),"&",np.round(theta9[109],4))
print("&",np.round(theta10[89],4),"&",np.round(theta10[99],4),"&",np.round(theta10[109],4))
print("&",np.round(theta11[89],4),"&",np.round(theta11[99],4),"&",np.round(theta11[109],4))
print("&",np.round(theta12[89],4),"&",np.round(theta12[99],4),"&",np.round(theta12[109],4))
# Out:
# & -5.6566 & -6.9325 & -3.1504
# & -7.5773 & -9.9351 & -7.3511
# & -12.5675 & -16.0253 & -14.5664
# & -11.3385 & -14.8692 & -13.517
# & -2.3581 & -1.2146 & 5.4214
# & -5.2527 & -6.0622 & -1.8047
# & -2.3705 & -1.2376 & 5.3948
# & -5.2634 & -6.0783 & -1.8152
# & -17.6973 & -20.6924 & -18.6658
# & -13.7224 & -16.9426 & -15.2528
# & 0.1211 & 1.2926 & 6.4305
# & -0.2234 & 2.2774 & 10.8572

# %%
print("&",np.round(rho1[89],4),"&",np.round(rho1[99],4),"&",np.round(rho1[109],4))
print("&",np.round(rho2[89],4),"&",np.round(rho2[99],4),"&",np.round(rho2[109],4))
print("&",np.round(rho3[89],4),"&",np.round(rho3[99],4),"&",np.round(rho3[109],4))
print("&",np.round(rho4[89],4),"&",np.round(rho4[99],4),"&",np.round(rho4[109],4))
print("&",np.round(rho5[89],4),"&",np.round(rho5[99],4),"&",np.round(rho5[109],4))
print("&",np.round(rho6[89],4),"&",np.round(rho6[99],4),"&",np.round(rho6[109],4))
print("&",np.round(rho7[89],4),"&",np.round(rho7[99],4),"&",np.round(rho7[109],4))
print("&",np.round(rho8[89],4),"&",np.round(rho8[99],4),"&",np.round(rho8[109],4))
print("&",np.round(rho9[89],4),"&",np.round(rho9[99],4),"&",np.round(rho9[109],4))
print("&",np.round(rho10[89],4),"&",np.round(rho10[99],4),"&",np.round(rho10[109],4))
print("&",np.round(rho11[89],4),"&",np.round(rho11[99],4),"&",np.round(rho11[109],4))
print("&",np.round(rho12[89],4),"&",np.round(rho12[99],4),"&",np.round(rho12[109],4))
# Out:
# & 4.5509 & 10.3319 & 16.2631
# & 5.1915 & 11.2802 & 17.203
# & 5.5971 & 11.7367 & 17.6
# & 5.741 & 11.9973 & 17.8694
# & 2.7205 & 7.3571 & 13.2517
# & 4.1042 & 9.7046 & 15.7701
# & 2.7447 & 7.3944 & 13.2746
# & 4.1196 & 9.7227 & 15.7738
# & 4.6252 & 10.2727 & 16.3004
# & 5.2134 & 11.2477 & 17.2369
# & 0.1038 & 0.6537 & 2.3753
# & 1.16 & 4.0686 & 9.0235

# %%
print(S_array[89],S_array[99],S_array[109])

print(call1[89],"&",call1[99],"&",call1[109])
print(call2[89],"&",call2[99],"&",call2[109])
print(call3[89],"&",call3[99],"&",call3[109])
print(call4[89],"&",call4[99],"&",call4[109])
p
print(call5[89],"&",call5[99],"&",call5[109])
print(call6[89],"&",call6[99],"&",call6[109])
print(call7[89],"&",call7[99],"&",call7[109])
print(call8[89],"&",call8[99],"&",call8[109])
print(call9[89],"&",call9[99],"&",call9[109])
print(call10[89],"&",call10[99],"&",call10[109])
print(call11[89],"&",call11[99],"&",call11[109])
print(call12[89],"&",call12[99],"&",call12[109])
# Out:
# 90 100 110
# 1.3669885735425074 & 4.725876814209307 & 10.516444440340749
# 1.7651603748823632 & 5.528929399066601 & 11.787662800085757
# 3.0007718739260985 & 7.09750823482739 & 13.68688296716211
# 2.622896236665907 & 6.769937458907053 & 13.4359711374128
# 1.3669885735425074 & 4.725876814209307 & 10.516444440340749
# 0.8456209644900152 & 3.0595920237913004 & 7.445095757607284
# 1.4084047123690533 & 4.524522123252059 & 10.060109465906333
# 0.8429315919137134 & 3.070801446255273 & 7.470675955131672
# 1.4080281690820284 & 4.53203859236274 & 10.073395092649529
# 4.531446642204606 & 8.239385967042677 & 14.368732468942271
# 3.365222844234208 & 7.300715150904785 & 13.732880755137716
# 0.0203010146855182 & 0.1580538100527563 & 0.7174479359435425
# 0.3056474736250038 & 1.393549066987415 & 4.068647993170835

# %%
fig = plt.figure()
plt.plot(S_array, call1, label='mean=0, var=1, lamda=0.1')#, c=color_array[i]
plt.plot(S_array, call2, label='mean=0, var=1, lamda=0.05')#, c=color_array[i]

plt.plot(S_array, call3, label='mean=0, var=0.5, lamda=0.1')#, c=color_array[i]
plt.plot(S_array, call4, label='mean=0, var=0.5, lamda=0.05')#, c=color_array[i]

plt.plot(S_array, call5, label='mean=0, var=1.5, lamda=0.1')#, c=color_array[i]
plt.plot(S_array, call6, label='mean=0, var=1.5, lamda=0.05')#, c=color_array[i]

plt.plot(S_array, call7, label='mean=0.5, var=1, lamda=0.1')#, c=color_array[i]
plt.plot(S_array, call8, label='mean=0.5, var=1, lamda=0.05')#, c=color_array[i]

plt.plot(S_array, call9, label='mean=0.5, var=0.5, lamda=0.1')#, c=color_array[i]
plt.plot(S_array, call10, label='mean=0.5, var=0.5, lamda=0.05')#, c=color_array[i]

plt.plot(S_array, call11, label='mean=0.5, var=1.5, lamda=0.1')#, c=color_array[i]
plt.plot(S_array, call12, label='mean=0.5, var=1.5, lamda=0.05')#, c=color_array[i]


plt.xlabel('$S_0$')
plt.ylabel('call value')
plt.title(f'DE call value')
plt.axvline(100, color='black', linestyle='dashed', linewidth=2, label="Strike")
plt.legend()
plt.show()
