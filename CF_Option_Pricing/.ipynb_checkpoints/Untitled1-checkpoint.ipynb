# %%
import pandas as pd
import glob
import os
import numpy as np

# %%
path_1 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/' # use your path
all_files_1 = glob.glob(os.path.join(path_1 , "*.csv"))

path_2 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/' # use your path
all_files_2 = glob.glob(os.path.join(path_2 , "*.csv"))

path_3 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_05/1_5/' # use your path
all_files_3 = glob.glob(os.path.join(path_3 , "*.csv"))

path_4 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_05/2/' # use your path
all_files_4 = glob.glob(os.path.join(path_4 , "*.csv"))

path_5 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_15/1_5/' # use your path
all_files_5 = glob.glob(os.path.join(path_5 , "*.csv"))

path_6 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_15/2/' # use your path
all_files_6 = glob.glob(os.path.join(path_6 , "*.csv"))

path_7 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_1/1_5/' # use your path
all_files_7 = glob.glob(os.path.join(path_7 , "*.csv"))

path_8 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_1/2/' # use your path
all_files_8 = glob.glob(os.path.join(path_8 , "*.csv"))

path_9 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_05/1_5/' # use your path
all_files_9 = glob.glob(os.path.join(path_9 , "*.csv"))

path_10 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_05/2/' # use your path
all_files_10 = glob.glob(os.path.join(path_10 , "*.csv"))

path_11 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_15/1_5/' # use your path
all_files_11 = glob.glob(os.path.join(path_11 , "*.csv"))

path_12 = r'/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_05_v_15/2/' # use your path
all_files_12 = glob.glob(os.path.join(path_12 , "*.csv"))

# %%
print(all_files_1)
print("----------------------")
print(all_files_1[5])
# Out:
# ['/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_Vega_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_rho_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_theta_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_call_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_gamma_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_delta_m_0_v_1_l_01_1.csv']
# ----------------------
# /Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/1_5/DG_delta_m_0_v_1_l_01_1.csv

# %%
print(all_files_2)
print("----------------------")
print(all_files_2[5])
# Out:
# ['/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_Vega_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_rho_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_theta_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_call_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_gamma_m_0_v_1_l_01_1.csv', '/Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_delta_m_0_v_1_l_01_1.csv']
# ----------------------
# /Users/huzuwang/我的雲端硬碟/code/實驗室code/python/CFOptionPricing2/data/DG/m_0_v_1/2/DG_delta_m_0_v_1_l_01_1.csv

# %%
# m 0 v 1 -----------------------------------------------------------------------------

# call
call_1 = all_files_1[3]
call_2 = all_files_2[3]

# delta
delta_1 = all_files_1[5]
delta_2 = all_files_2[5]

# gamma
gamma_1 = all_files_1[4]
gamma_2 = all_files_2[4]

# theta
theta_1 = all_files_1[2]
theta_2 = all_files_2[2]

# Vega
vega_1 = all_files_1[0]
vega_2 = all_files_2[0]

# rho
rho_1 = all_files_1[1]
rho_2 = all_files_2[1]

# m_0_v_05-----------------------------------------------------------------------------
# call
call_3 = all_files_3[3]
call_4 = all_files_4[3]

# delta
delta_3 = all_files_3[5]
delta_4 = all_files_4[5]

# gamma
gamma_3 = all_files_3[4]
gamma_4 = all_files_4[4]

# theta
theta_3 = all_files_3[2]
theta_4 = all_files_4[2]

# Vega
vega_3 = all_files_3[0]
vega_4 = all_files_4[0]

# rho
rho_3 = all_files_3[1]
rho_4 = all_files_4[1]

# m_0_v_15-----------------------------------------------------------------------------
# call
call_5 = all_files_5[3]
call_6 = all_files_6[3]

# delta
delta_5 = all_files_5[5]
delta_6 = all_files_6[5]

# gamma
gamma_5 = all_files_5[4]
gamma_6 = all_files_6[4]

# theta
theta_5 = all_files_5[2]
theta_6 = all_files_6[2]

# Vega
vega_5 = all_files_5[0]
vega_6 = all_files_6[0]

# rho
rho_5 = all_files_5[1]
rho_6 = all_files_6[1] 
# m_05_v_1-----------------------------------------------------------------------------
# call
call_7 = all_files_7[3]
call_8 = all_files_8[3]

# delta
delta_7 = all_files_7[5]
delta_8 = all_files_8[5]

# gamma
gamma_7 = all_files_7[4]
gamma_8 = all_files_8[4]

# theta
theta_7 = all_files_7[2]
theta_8 = all_files_8[2]

# Vega
vega_7 = all_files_7[0]
vega_8 = all_files_8[0]

# rho
rho_7 = all_files_7[1]
rho_8 = all_files_8[1]

# m_05_v_05-----------------------------------------------------------------------------

# call
call_9 = all_files_9[3]
call_10 = all_files_10[3]

# delta
delta_9 = all_files_9[5]
delta_10 = all_files_10[5]

# gamma
gamma_9 = all_files_9[4]
gamma_10 = all_files_10[4]

# theta
theta_9 = all_files_9[2]
theta_10 = all_files_10[2]

# Vega
vega_9 = all_files_9[0]
vega_10 = all_files_10[0]

# rho
rho_9 = all_files_9[1]
rho_10 = all_files_10[1]
# m_05_v_15-----------------------------------------------------------------------------
# call
call_11 = all_files_11[3]
call_12 = all_files_12[3]

# delta
delta_11 = all_files_11[5]
delta_12 = all_files_12[5]

# gamma
gamma_11 = all_files_11[4]
gamma_12 = all_files_12[4]

# theta
theta_11 = all_files_11[2]
theta_12 = all_files_12[2]

# Vega
vega_11 = all_files_11[0]
vega_12 = all_files_12[0]

# rho
rho_11 = all_files_11[1]
rho_12 = all_files_12[1]

# %%
dfa = pd.read_csv(call_5, index_col=None, header=0)

# %%
dfb = pd.read_csv(call_6, index_col=None, header=0)

# %%
df0 = dfa.iloc[89,1:]
df1 = dfa.iloc[99,1:]
df2 = dfa.iloc[109,1:]
df3 = pd.concat([df0,df1, df2], axis=1)
print(df3)
print("----------------------------")
df3 = np.array(df3)
print(df3)

shape1 = np.shape(df3)[0]
shape2 = np.shape(df3)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape1):
    a = ''
    for j in range(shape2):
        a = a + f' & {np.round(df3[i][j],4)}'
    print('$\beta = 1.5$ &',a,"\\",'\\')
# Out:
#           89        99         109
# p01  0.000826  0.011061   0.079971
# p02  0.465636  1.943948   5.291889
# p03  0.941689  3.343799   8.023936
# p04  1.213836  4.055947   9.291375
# p05  1.389856  4.492886  10.037451
# p06  1.520737  4.807303  10.560315
# p07  1.631574  5.066948  10.983220
# p08  1.739344  5.313666  11.377447
# p09  1.866119  5.596720  11.820482
# ----------------------------
# [[8.26065124e-04 1.10611260e-02 7.99708496e-02]
#  [4.65635506e-01 1.94394753e+00 5.29188919e+00]
#  [9.41689458e-01 3.34379885e+00 8.02393638e+00]
#  [1.21383604e+00 4.05594661e+00 9.29137530e+00]
#  [1.38985618e+00 4.49288619e+00 1.00374509e+01]
#  [1.52073726e+00 4.80730269e+00 1.05603155e+01]
#  [1.63157367e+00 5.06694811e+00 1.09832196e+01]
#  [1.73934449e+00 5.31366642e+00 1.13774473e+01]
#  [1.86611862e+00 5.59672010e+00 1.18204819e+01]]
# ----------------------------
# ----------------------------
#
# $\ beta = 1.5$ &  & 0.0008 & 0.0111 & 0.08 \ \
# ...

# %%
df0 = dfb.iloc[89,1:]
df1 = dfb.iloc[99,1:]
df2 = dfb.iloc[109,1:]
df3 = pd.concat([df0,df1, df2], axis=1)
print(df3)
print("----------------------------")
df3 = np.array(df3)
print(df3)

shape1 = np.shape(df3)[0]
shape2 = np.shape(df3)[1]
print("----------------------------")
print("----------------------------")
print("")
for i in range(shape1):
    a = ''
    for j in range(shape2):
        a = a + f' & {np.round(df3[i][j],4)}'
    print('$\beta = 2$&',a)
# Out:
#           89        99         109
# p01  0.083660  0.501036   1.826788
# p02  0.837326  3.056963   7.494690
# p03  1.219327  4.070786   9.320149
# p04  1.423255  4.575774  10.181735
# p05  1.556306  4.894233  10.710636
# p06  1.657331  5.130564  11.095733
# p07  1.744536  5.330587  11.416039
# p08  1.830402  5.523524  11.719142
# p09  1.931942  5.746146  12.060964
# ----------------------------
# [[ 0.08365972  0.50103564  1.82678778]
#  [ 0.83732594  3.05696334  7.49468952]
#  [ 1.21932684  4.07078579  9.3201494 ]
#  [ 1.42325457  4.57577354 10.18173469]
#  [ 1.55630639  4.89423326 10.71063571]
#  [ 1.65733078  5.13056356 11.09573252]
#  [ 1.74453626  5.33058704 11.41603873]
#  [ 1.8304017   5.52352383 11.71914168]
#  [ 1.93194206  5.74614554 12.06096366]]
# ----------------------------
# ----------------------------
#
#  & 0.0837 & 0.501 & 1.8268
#  & 0.8373 & 3.057 & 7.4947
#  & 1.2193 & 4.0708 & 9.3201
#  & 1.4233 & 4.5758 & 10.1817
#  & 1.5563 & 4.8942 & 10.7106
# ...
